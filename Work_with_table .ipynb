# %%
import pandas as pd

# %%
d19 = pd.read_csv('data2019.csv')

# %%
d20 = pd.read_csv('data2020.csv')

# %%
fac = pd.read_csv('fnew.csv', sep = ';', encoding='cp1251')

# %%
f20 = pd.read_csv('f20.csv')

# %%
f19 = pd.read_csv('abit_subs.csv')

# %%
d19.head()
# Out:
#           id first_name  last_name  deactivated  is_closed  sex  \
# 0  207716367      Роман  Кравченко          NaN      False    2
# 1  231723221        Юля  Усольцева          NaN      False    1
# 2  229607742        Оля    Маркова          NaN      False    1
# 3  273357176     Сонали      Оджха          NaN      False    1
# 4  269501175  Александр   Порфиров          NaN      False    2
#
#                                       photo_400_orig  verified  \
# 0  https://sun9-54.userapi.com/c854016/v854016489...         0
# 1  https://sun9-8.userapi.com/c852132/v852132722/...         0
# 2  https://sun9-53.userapi.com/c857520/v857520235...         0
# 3  https://sun9-1.userapi.com/c858120/v858120366/...         0
# 4  https://sun9-62.userapi.com/c856520/v856520652...         0
#
#                           domain       bdate  ...  \
# 0     https://vk.com/roman_01rus  10.10.2001  ...
# 1  https://vk.com/usoltsevayulia      26.май  ...
# ...

# %%
d20.head()
# Out:
#           id first_name last_name  deactivated  is_closed  sex  \
# 0  457721481   Виктория  Сергеева          NaN      False    1
# 1  348918738       Женя    Крутых          NaN      False    2
# 2  334640534    Шукрона   Орзуева          NaN      False    1
# 3  503381801       Кеша   Баронов          NaN      False    2
# 4  543687679       Лиля  Миронова          NaN      False    1
#
#                                       photo_400_orig  verified  \
# 0  https://sun9-4.userapi.com/c834103/v834103172/...         0
# 1  https://sun9-72.userapi.com/c856128/v856128961...         0
# 2  https://sun9-69.userapi.com/c850336/v850336660...         0
# 3         https://vk.com/images/camera_400.png?ava=1         0
# 4  https://sun9-55.userapi.com/c855224/v855224770...         0
#
#                         domain       bdate  ...  has_photo  \
# 0   https://vk.com/id457721481  14.03.2003  ...          1
# 1   https://vk.com/id348918738  23.05.2003  ...          1
# ...

# %%
set(d19.columns) - set(d20.columns)
# Out:
# {'Артикул новый'}

# %%
f19.head()
# Out:
#      user_id   user_items                                       public_items  \
# 0  207716367           {}  {71729358,67580761,57846937,66678575,460389,71...
# 1  231723221  {479508764}  {80519623,105241987,120967338,58170807,1150045...
# 2  229607742           {}  {41396644,160650104,163153046,66678575,1119368...
# 3  273357176           {}  {149467658,83815413,96913110,143295731,1722121...
# 4  269501175           {}  {110949564,40390678,48562858,38001257,57846937...
#
#                                          group_items
# 0  {71729358,67580761,57846937,66678575,460389,71...
# 1  {105241987,85835067,120967338,80519623,5817080...
# 2  {41396644,160650104,102881445,175466152,139702...
# 3  {149467658,83815413,19977823,96913110,17221215...
# 4  {40390678,110949564,59824456,38001257,15772758...

# %%
f20.head()
# Out:
#      user_id                                             groups  \
# 0  348918738                                          142229237
# 1  334640534  19043,28322985,52764119,145543730,15302785,791...
# 2  503381801                                                NaN
# 3  543687679                                           27775456
# 4  532358638                        41599966,85495094,178181599
#
#                                              publics
# 0  29642594,85587072,123608439,114211332,11118110...
# 1  151221891,96936554,168315084,140776989,8736833...
# 2  162463319,60533269,141731737,100667517,5382334...
# 3  150909727,125770269,132565509,94797716,6822917...
# 4                                150250181,162189707

# %%
f19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14931 entries, 0 to 14930
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       14931 non-null  int64
#  1   user_items    14931 non-null  object
#  2   public_items  14931 non-null  object
#  3   group_items   14759 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 466.7+ KB

# %%
f20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  2326 non-null   int64
#  1   groups   1600 non-null   object
#  2   publics  2232 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 54.6+ KB

# %%
f19.rename(columns = {'user_id':'id'}, inplace = True)
f20.rename(columns = {'user_id':'id'}, inplace = True)

# %%
f19.rename(columns={'group_items':'groups'}, inplace = True)
f19.rename(columns={'public_items':'publics'}, inplace = True)

# %%
f20
# Out:
#              id                                             groups  \
# 0     348918738                                          142229237
# 1     334640534  19043,28322985,52764119,145543730,15302785,791...
# 2     503381801                                                NaN
# 3     543687679                                           27775456
# 4     532358638                        41599966,85495094,178181599
# ...         ...                                                ...
# 2321  278958946                                                NaN
# 2322  164832018                                                NaN
# 2323  459850552  84600270,170528132,176538220,137839839,9279792...
# 2324  316833295  109658801,155293068,148289111,151255339,151414...
# 2325  325852364  148289111,151204563,111263598,123692663,281078...
#
#                                                 publics
# 0     29642594,85587072,123608439,114211332,11118110...
# ...

# %%
fac.head()
# Out:
#   universities_faculty_id                          universities_faculty_name  \
# 0                  334469                           Факультет естествознания
# 1                  252346           Факультет математики и компьютерных наук
# 2                  298489               Институт физической культуры и дзюдо
# 3                  245679                     Инженерно-физический факультет
# 4                  173443  Факультет информационных систем в экономике и ...
#
#           ПредмОбл Итог   Направление
# 0                другое  естественные
# 1            математика        точные
# 2     биология/медицина  естественные
# 3                физика        точные
# 4  техника и технологии        точные

# %%
fac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2672 entries, 0 to 2671
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   universities_faculty_id    1805 non-null   object
#  1   universities_faculty_name  2671 non-null   object
#  2   ПредмОбл Итог              2672 non-null   object
#  3   Направление                2672 non-null   object
# dtypes: object(4)
# memory usage: 83.6+ KB

# %%
def find_f(row, f):
    s = row['universities']
    ids = []
    t = False
    t1 = False
    try: 
        if s.find('faculty_name') > -1 :
            if s.split(',')[7].split(':')[1].strip('}]"" ') in f['universities_faculty_name'].unique():
                t = True
                print(s.split(',')[7].split(':')[1].strip('}]"" '))
    except IndexError:
        if s.split(',')[5].split(':')[1].strip('}]"" ') in f['universities_faculty_name'].unique():
            t1 = True
            print(s.split(',')[5].split(':')[1].strip('}]"" '))
    if t:
        return s.split(',')[7].split(':')[1].strip('}]"" ')
    elif t1:
        return s.split(',')[5].split(':')[1].strip('}]"" ')
    else:
        return 0
d19['universities_faculty_name'] = d19.apply (lambda row: find_f(row, fac), axis=1)
# Out:
# Факультет вычислительной математики и кибернетики
# Юридический факультет
# Переводческий факультет
# Институт бизнеса и делового администрирования
# Факультет спорта
# Филологический факультет
# Институт экономики
# Факультет управления
# Факультет информационных систем в экономике и юриспруденции
# Факультет «Безопасность жизнедеятельности и инженерная экология»
# Институт филологии
# Факультет экономики и управления
# Факультет иностранных языков
# Академия архитектуры и искусств
# Инженерно-физический факультет
# Факультет педагогики и психологии
# Стоматологический факультет
# Юридический институт
# Экономико-юридический факультет
# Факультет бизнеса
# Институт архитектуры и градостроительства (Архитектурно-градостроительный факультет)
# Психолого-педагогический факультет
# Восточный институт - Школа региональных и международных исследований
# Экономико-юридический факультет
# Психолого-педагогический факультет
# Юридический факультет
# Геолого-географический факультет
# ...

# %%
d19
# Out:
#               id first_name  last_name  deactivated  is_closed  sex  \
# 0      207716367      Роман  Кравченко          NaN      False    2
# 1      231723221        Юля  Усольцева          NaN      False    1
# 2      229607742        Оля    Маркова          NaN      False    1
# 3      273357176     Сонали      Оджха          NaN      False    1
# 4      269501175  Александр   Порфиров          NaN      False    2
# ...          ...        ...        ...          ...        ...  ...
# 15080  139033455       Даша   Смирнова          NaN      False    1
# 15081  461863958  Анастасия     Лисица          NaN      False    1
# 15082  223051477  Елизавета   Сергеева          NaN      False    1
# 15083  101744396  Екатерина   Сатюкова          NaN      False    1
# 15084  215187435  Екатерина  Пиленкова          NaN      False    1
#
#                                           photo_400_orig  verified  \
# 0      https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
d19['universities'][2417].split(',')
# Out:
# ['[{"id": 61117',
#  ' "city": 161',
#  ' "name": "ЗабИЖТ (филиал ИрГУПС)"',
#  ' "country": 1',
#  ' "faculty": 215494',
#  ' "faculty_name": "Электроснабжение железных дорог"',
#  ' "education_status": "Абитуриент"}]']

# %%
d19['universities_faculty_name'][2417]
# Out:
# 'Электроснабжение железных дорог'

# %%
def find_f(row, f):
    s = row['universities']
    ids = []
    t = False
    t1 = False
    try: 
        if s.find('faculty_name') > -1 :
            if s.split(',')[7].split(':')[1].strip('}]"" ') in f['universities_faculty_name'].unique():
                t = True
                print(s.split(',')[7].split(':')[1].strip('}]"" '))
    except IndexError:
        if s.split(',')[5].split(':')[1].strip('}]"" ') in f['universities_faculty_name'].unique():
            t1 = True
            print(s.split(',')[5].split(':')[1].strip('}]"" '))
    if t:
        return s.split(',')[7].split(':')[1].strip('}]"" ')
    elif t1:
        return s.split(',')[5].split(':')[1].strip('}]"" ')
    else:
        return 0
d20['universities_faculty_name'] = d20.apply (lambda row: find_f(row, fac), axis=1)
# Out:
# Биологический факультет
# Факультет дизайна
# Высшая школа бизнеса
# Приборостроительный факультет
# Факультет журналистики
# Учётный факультет
# Факультет искусств
# Факультет биоинженерии и биоинформатики
# Радиотехнический факультет
# Радиотехнический факультет
# Радиотехнический факультет
# Кафедра «Контроль и качество»
# Факультет международных экономических отношений
# Лечебный факультет
# Факультет психологии
# Высшая школа бизнеса
# Факультет государственного и муниципального управления
# Институт специальной подготовки
# Юридический факультет
# Стоматологический факультет
# Медицинский институт
# Физический факультет
# Физический факультет
# Экономический факультет
# Факультет журналистики
# Биологический факультет
# Факультет вычислительной математики и кибернетики
# Институт бизнеса и делового администрирования
# Институт прикладных информационных технологий и коммуникаций
# Факультет искусств
# Факультет журналистики
# Факультет пожарной безопасности
# ...

# %%
d20.head()
# Out:
#           id first_name last_name  deactivated  is_closed  sex  \
# 0  457721481   Виктория  Сергеева          NaN      False    1
# 1  348918738       Женя    Крутых          NaN      False    2
# 2  334640534    Шукрона   Орзуева          NaN      False    1
# 3  503381801       Кеша   Баронов          NaN      False    2
# 4  543687679       Лиля  Миронова          NaN      False    1
#
#                                       photo_400_orig  verified  \
# 0  https://sun9-4.userapi.com/c834103/v834103172/...         0
# 1  https://sun9-72.userapi.com/c856128/v856128961...         0
# 2  https://sun9-69.userapi.com/c850336/v850336660...         0
# 3         https://vk.com/images/camera_400.png?ava=1         0
# 4  https://sun9-55.userapi.com/c855224/v855224770...         0
#
#                         domain       bdate  ...  \
# 0   https://vk.com/id457721481  14.03.2003  ...
# 1   https://vk.com/id348918738  23.05.2003  ...
# 2  https://vk.com/gera18072006  27.01.2003  ...
# ...

# %%
d19.drop(['Артикул новый'], axis = 1, inplace = True)

# %%
df = pd.concat([d19,d20])

# %%
df
# Out:
#              id first_name  last_name  deactivated  is_closed  sex  \
# 0     207716367      Роман  Кравченко          NaN      False    2
# 1     231723221        Юля  Усольцева          NaN      False    1
# 2     229607742        Оля    Маркова          NaN      False    1
# 3     273357176     Сонали      Оджха          NaN      False    1
# 4     269501175  Александр   Порфиров          NaN      False    2
# ...         ...        ...        ...          ...        ...  ...
# 2752  278958946       Юрий    Мамедов          NaN      False    2
# 2753  164832018     Максим  Патрацкий          NaN      False    2
# 2754  459850552      Kolya    Guschin          NaN      False    2
# 2755  316833295     Марина   Тарасова          NaN      False    1
# 2756  325852364  Анастасия   Тихонова          NaN      False    1
#
#                                          photo_400_orig  verified  \
# 0     https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
fac.drop('universities_faculty_id', axis = 1, inplace = True)

# %%
fac
# Out:
#                               universities_faculty_name         ПредмОбл Итог  \
# 0                              Факультет естествознания                другое
# 1              Факультет математики и компьютерных наук            математика
# 2                  Институт физической культуры и дзюдо     биология/медицина
# 3                        Инженерно-физический факультет                физика
# 4     Факультет информационных систем в экономике и ...  техника и технологии
# ...                                                 ...                   ...
# 2667  Юридический факультет (Институт экономики и пр...         юриспруденция
# 2668           Юридический факультет (Морская академия)         юриспруденция
# 2669                                      Юриспруденции         юриспруденция
# 2670                                      Юриспруденция         юриспруденция
# 2671                                      Юриспруденция         юриспруденция
#
#        Направление
# ...

# %%
fac.drop_duplicates(keep='first', inplace=True)

# %%
for line in fac.values:
    data = fac[fac['universities_faculty_name'] == line[0]]
    if data['ПредмОбл Итог'].nunique() > 1:
        print(line)

# %%
dfs = df.merge(fac,on = ['universities_faculty_name'],how = 'left')
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17842 entries, 0 to 17841
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         17842 non-null  int64
#  1   first_name                 17842 non-null  object
#  2   last_name                  17842 non-null  object
#  3   deactivated                0 non-null      float64
#  4   is_closed                  17842 non-null  bool
#  5   sex                        17842 non-null  int64
#  6   photo_400_orig             17193 non-null  object
#  7   verified                   17842 non-null  int64
#  8   domain                     17842 non-null  object
#  9   bdate                      16890 non-null  object
#  10  last_seen                  17842 non-null  int64
#  11  maiden_name                133 non-null    object
#  12  city_id                    15301 non-null  float64
# ...

# %%
dfs
# Out:
#               id first_name  last_name  deactivated  is_closed  sex  \
# 0      207716367      Роман  Кравченко          NaN      False    2
# 1      231723221        Юля  Усольцева          NaN      False    1
# 2      229607742        Оля    Маркова          NaN      False    1
# 3      273357176     Сонали      Оджха          NaN      False    1
# 4      269501175  Александр   Порфиров          NaN      False    2
# ...          ...        ...        ...          ...        ...  ...
# 17837  278958946       Юрий    Мамедов          NaN      False    2
# 17838  164832018     Максим  Патрацкий          NaN      False    2
# 17839  459850552      Kolya    Guschin          NaN      False    2
# 17840  316833295     Марина   Тарасова          NaN      False    1
# 17841  325852364  Анастасия   Тихонова          NaN      False    1
#
#                                           photo_400_orig  verified  \
# 0      https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
f = pd.concat([f19,f20])

# %%
f
# Out:
#              id   user_items  \
# 0     207716367           {}
# 1     231723221  {479508764}
# 2     229607742           {}
# 3     273357176           {}
# 4     269501175           {}
# ...         ...          ...
# 2321  278958946          NaN
# 2322  164832018          NaN
# 2323  459850552          NaN
# 2324  316833295          NaN
# 2325  325852364          NaN
#
#                                                 publics  \
# 0     {71729358,67580761,57846937,66678575,460389,71...
# 1     {80519623,105241987,120967338,58170807,1150045...
# 2     {41396644,160650104,163153046,66678575,1119368...
# 3     {149467658,83815413,96913110,143295731,1722121...
# 4     {110949564,40390678,48562858,38001257,57846937...
# ...                                                 ...
# 2321  183467877,91050183,32370614,150261522,22477631...
# 2322  120254617,163058008,41437811,33409465,15430681...
# 2323  141959356,149478522,52537634,25161110,18405212...
# ...

# %%
f.drop_duplicates(keep='first', inplace = True)

# %%
dfs
# Out:
#               id first_name  last_name  deactivated  is_closed  sex  \
# 0      207716367      Роман  Кравченко          NaN      False    2
# 1      231723221        Юля  Усольцева          NaN      False    1
# 2      229607742        Оля    Маркова          NaN      False    1
# 3      273357176     Сонали      Оджха          NaN      False    1
# 4      269501175  Александр   Порфиров          NaN      False    2
# ...          ...        ...        ...          ...        ...  ...
# 17837  278958946       Юрий    Мамедов          NaN      False    2
# 17838  164832018     Максим  Патрацкий          NaN      False    2
# 17839  459850552      Kolya    Guschin          NaN      False    2
# 17840  316833295     Марина   Тарасова          NaN      False    1
# 17841  325852364  Анастасия   Тихонова          NaN      False    1
#
#                                           photo_400_orig  verified  \
# 0      https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
dfs1 = dfs.merge(f,on = ['id'],how = 'left')

# %%
dfs1
# Out:
#               id first_name  last_name  deactivated  is_closed  sex  \
# 0      207716367      Роман  Кравченко          NaN      False    2
# 1      231723221        Юля  Усольцева          NaN      False    1
# 2      229607742        Оля    Маркова          NaN      False    1
# 3      273357176     Сонали      Оджха          NaN      False    1
# 4      269501175  Александр   Порфиров          NaN      False    2
# ...          ...        ...        ...          ...        ...  ...
# 17869  278958946       Юрий    Мамедов          NaN      False    2
# 17870  164832018     Максим  Патрацкий          NaN      False    2
# 17871  459850552      Kolya    Guschin          NaN      False    2
# 17872  316833295     Марина   Тарасова          NaN      False    1
# 17873  325852364  Анастасия   Тихонова          NaN      False    1
#
#                                           photo_400_orig  verified  \
# 0      https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
dfs1.drop_duplicates(keep='first', inplace = True)

# %%
dfs1
# Out:
#               id first_name  last_name  deactivated  is_closed  sex  \
# 0      207716367      Роман  Кравченко          NaN      False    2
# 1      231723221        Юля  Усольцева          NaN      False    1
# 2      229607742        Оля    Маркова          NaN      False    1
# 3      273357176     Сонали      Оджха          NaN      False    1
# 4      269501175  Александр   Порфиров          NaN      False    2
# ...          ...        ...        ...          ...        ...  ...
# 17868  155756764    Дмитрий   Дегтярёв          NaN      False    2
# 17869  278958946       Юрий    Мамедов          NaN      False    2
# 17870  164832018     Максим  Патрацкий          NaN      False    2
# 17871  459850552      Kolya    Guschin          NaN      False    2
# 17873  325852364  Анастасия   Тихонова          NaN      False    1
#
#                                           photo_400_orig  verified  \
# 0      https://sun9-54.userapi.com/c854016/v854016489...         0
# ...

# %%
export_csv = dfs1.to_csv (r'data.csv', index = None, header=True)

# %%
f[f['id'] == 231723221]
# Out:
#           id   user_items                                            publics  \
# 1  231723221  {479508764}  {80519623,105241987,120967338,58170807,1150045...
#
#                                               groups
# 1  {105241987,85835067,120967338,80519623,5817080...
